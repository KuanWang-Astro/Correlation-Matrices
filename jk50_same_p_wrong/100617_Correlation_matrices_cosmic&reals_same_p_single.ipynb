# %%
import numpy as np
import matplotlib.pyplot as plt
np.set_printoptions(threshold=np.inf)
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
from cosmic_correlation_matrix_single import correlation

# %%
consuelo_20p0_w = np.load('consuelo_20p0_jk_w.npz')
consuelo_20p0_wo = np.load('consuelo_20p0_jk_wo.npz')
consuelo_20p5_w = np.load('consuelo_20p5_jk_w.npz')
consuelo_20p5_wo = np.load('consuelo_20p5_jk_wo.npz')
consuelo_21p0_w = np.load('consuelo_21p0_jk_w.npz')
consuelo_21p0_wo = np.load('consuelo_21p0_jk_wo.npz')

chinchilla512_20p0_w = np.load('chinchilla512_20p0_jk_w.npz')
chinchilla512_20p0_wo = np.load('chinchilla512_20p0_jk_wo.npz')
chinchilla512_20p5_w = np.load('chinchilla512_20p5_jk_w.npz')
chinchilla512_20p5_wo = np.load('chinchilla512_20p5_jk_wo.npz')
chinchilla512_21p0_w = np.load('chinchilla512_21p0_jk_w.npz')
chinchilla512_21p0_wo = np.load('chinchilla512_21p0_jk_wo.npz')

chinchilla1024_20p0_w = np.load('chinchilla1024_20p0_jk_w.npz')
chinchilla1024_20p0_wo = np.load('chinchilla1024_20p0_jk_wo.npz')
chinchilla1024_20p5_w = np.load('chinchilla1024_20p5_jk_w.npz')
chinchilla1024_20p5_wo = np.load('chinchilla1024_20p5_jk_wo.npz')
chinchilla1024_21p0_w = np.load('chinchilla1024_21p0_jk_w.npz')
chinchilla1024_21p0_wo = np.load('chinchilla1024_21p0_jk_wo.npz')

chinchilla2048_20p0_w = np.load('chinchilla2048_20p0_jk_w.npz')
chinchilla2048_20p0_wo = np.load('chinchilla2048_20p0_jk_wo.npz')
chinchilla2048_20p5_w = np.load('chinchilla2048_20p5_jk_w.npz')
chinchilla2048_20p5_wo = np.load('chinchilla2048_20p5_jk_wo.npz')
chinchilla2048_21p0_w = np.load('chinchilla2048_21p0_jk_w.npz')
chinchilla2048_21p0_wo = np.load('chinchilla2048_21p0_jk_wo.npz')

chinchilla2560_20p0_w = np.load('chinchilla2560_20p0_jk_w.npz')
chinchilla2560_20p0_wo = np.load('chinchilla2560_20p0_jk_wo.npz')
chinchilla2560_20p5_w = np.load('chinchilla2560_20p5_jk_w.npz')
chinchilla2560_20p5_wo = np.load('chinchilla2560_20p5_jk_wo.npz')
chinchilla2560_21p0_w = np.load('chinchilla2560_21p0_jk_w.npz')
chinchilla2560_21p0_wo = np.load('chinchilla2560_21p0_jk_wo.npz')

bolshoi_20p0_w = np.load('bolshoi_20p0_jk_w.npz')
bolshoi_20p0_wo = np.load('bolshoi_20p0_jk_wo.npz')
bolshoi_20p5_w = np.load('bolshoi_20p5_jk_w.npz')
bolshoi_20p5_wo = np.load('bolshoi_20p5_jk_wo.npz')
bolshoi_21p0_w = np.load('bolshoi_21p0_jk_w.npz')
bolshoi_21p0_wo = np.load('bolshoi_21p0_jk_wo.npz')

bolplanck_20p0_w = np.load('bolplanck_20p0_jk_w.npz')
bolplanck_20p0_wo = np.load('bolplanck_20p0_jk_wo.npz')
bolplanck_20p5_w = np.load('bolplanck_20p5_jk_w.npz')
bolplanck_20p5_wo = np.load('bolplanck_20p5_jk_wo.npz')
bolplanck_21p0_w = np.load('bolplanck_21p0_jk_w.npz')
bolplanck_21p0_wo = np.load('bolplanck_21p0_jk_wo.npz')

diemer250_20p0_w = np.load('diemer250_20p0_jk_w.npz')
diemer250_20p0_wo = np.load('diemer250_20p0_jk_wo.npz')
diemer250_20p5_w = np.load('diemer250_20p5_jk_w.npz')
diemer250_20p5_wo = np.load('diemer250_20p5_jk_wo.npz')
diemer250_21p0_w = np.load('diemer250_21p0_jk_w.npz')
diemer250_21p0_wo = np.load('diemer250_21p0_jk_wo.npz')

diemer500_20p0_w = np.load('diemer500_20p0_jk_w.npz')
diemer500_20p0_wo = np.load('diemer500_20p0_jk_wo.npz')
diemer500_20p5_w = np.load('diemer500_20p5_jk_w.npz')
diemer500_20p5_wo = np.load('diemer500_20p5_jk_wo.npz')
diemer500_21p0_w = np.load('diemer500_21p0_jk_w.npz')
diemer500_21p0_wo = np.load('diemer500_21p0_jk_wo.npz')

# %%
title_list = ['chinchilla2560,-20.0','chinchilla2560,-20.5','chinchilla2560,-21.0',\
              'bolshoi,-20.0','bolshoi,-20.5','bolshoi,-21.0',\
              'chinchilla2048,-20.0','chinchilla2048,-20.5','chinchilla2048,-21.0',\
              'bolplanck,-20.0','bolplanck,-20.5','bolplanck,-21.0',\
              'chinchilla1024,-20.0','chinchilla1024,-20.5','chinchilla1024,-21.0',\
              'diemer250,-20.0','diemer250,-20.5','diemer250,-21.0',\
              'consuelo,-20.0','consuelo,-20.5','consuelo,-21.0',\
              'diemer500,-20.0','diemer500,-20.5','diemer500,-21.0',\
              'chinchilla512,-20.0','chinchilla512,-20.5','chinchilla512,-21.0']

# %%
c = []

c.append(correlation(chinchilla2560_20p0_w,chinchilla2560_20p0_wo))
c.append(correlation(chinchilla2560_20p5_w,chinchilla2560_20p5_wo))
c.append(correlation(chinchilla2560_21p0_w,chinchilla2560_21p0_wo))

c.append(correlation(bolshoi_20p0_w,bolshoi_20p0_wo))
c.append(correlation(bolshoi_20p5_w,bolshoi_20p5_wo))
c.append(correlation(bolshoi_21p0_w,bolshoi_21p0_wo))

c.append(correlation(chinchilla2048_20p0_w,chinchilla2048_20p0_wo))
c.append(correlation(chinchilla2048_20p5_w,chinchilla2048_20p5_wo))
c.append(correlation(chinchilla2048_21p0_w,chinchilla2048_21p0_wo))

c.append(correlation(bolplanck_20p0_w,bolplanck_20p0_wo))
c.append(correlation(bolplanck_20p5_w,bolplanck_20p5_wo))
c.append(correlation(bolplanck_21p0_w,bolplanck_21p0_wo))

c.append(correlation(chinchilla1024_20p0_w,chinchilla1024_20p0_wo))
c.append(correlation(chinchilla1024_20p5_w,chinchilla1024_20p5_wo))
c.append(correlation(chinchilla1024_21p0_w,chinchilla1024_21p0_wo))

c.append(correlation(diemer250_20p0_w,diemer250_20p0_wo))
c.append(correlation(diemer250_20p5_w,diemer250_20p5_wo))
c.append(correlation(diemer250_21p0_w,diemer250_21p0_wo))

c.append(correlation(consuelo_20p0_w,consuelo_20p0_wo))
c.append(correlation(consuelo_20p5_w,consuelo_20p5_wo))
c.append(correlation(consuelo_21p0_w,consuelo_21p0_wo))

c.append(correlation(diemer500_20p0_w,diemer500_20p0_wo))
c.append(correlation(diemer500_20p5_w,diemer500_20p5_wo))
c.append(correlation(diemer500_21p0_w,diemer500_21p0_wo))

c.append(correlation(chinchilla512_20p0_w,chinchilla512_20p0_wo))
c.append(correlation(chinchilla512_20p5_w,chinchilla512_20p5_wo))
c.append(correlation(chinchilla512_21p0_w,chinchilla512_21p0_wo))

# %%
fig = plt.figure(figsize=(30,90))
for i in range(1,28):
    fig.add_subplot(9,3,i)
    plt.title(title_list[i-1],fontsize=30)
    c[i-1].plot_correlation_matrix(1,-1)
