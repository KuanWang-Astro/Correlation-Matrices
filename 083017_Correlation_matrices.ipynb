# %%
import numpy as np
import matplotlib.pyplot as plt
np.set_printoptions(threshold=np.inf)
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
from correlation_matrix import correlation

# %%
all_w_512 = np.load('../Compute statistics new/chinchilla512_w.npz')
all_wo_512 = np.load('../Compute statistics new/chinchilla512_wo.npz')

# %%
c = correlation(all_w_512,all_wo_512)

# %%
c.plot_correlation_matrix()
