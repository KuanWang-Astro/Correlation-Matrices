# %%
import numpy as np
import matplotlib.pyplot as plt
np.set_printoptions(threshold=np.inf)
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
from correlation_matrix import correlation

# %%
consuelo_20p0_w = np.load('083017_consuelo_20p0_1_w.npz')
consuelo_20p0_wo = np.load('083017_consuelo_20p0_1_wo.npz')
consuelo_20p5_w = np.load('083017_consuelo_20p5_1_w.npz')
consuelo_20p5_wo = np.load('083017_consuelo_20p5_1_wo.npz')
consuelo_21p0_w = np.load('083017_consuelo_21p0_1_w.npz')
consuelo_21p0_wo = np.load('083017_consuelo_21p0_1_wo.npz')

chinchilla512_20p0_w = np.load('083017_chinchilla512_20p0_w.npz')
chinchilla512_20p0_wo = np.load('083017_chinchilla512_20p0_wo.npz')
chinchilla512_20p5_w = np.load('083017_chinchilla512_20p5_w.npz')
chinchilla512_20p5_wo = np.load('083017_chinchilla512_20p5_wo.npz')
chinchilla512_21p0_w = np.load('083017_chinchilla512_21p0_w.npz')
chinchilla512_21p0_wo = np.load('083017_chinchilla512_21p0_wo.npz')

chinchilla1024_20p0_w = np.load('083017_chinchilla1024_20p0_w.npz')
chinchilla1024_20p0_wo = np.load('083017_chinchilla1024_20p0_wo.npz')
chinchilla1024_20p5_w = np.load('083017_chinchilla1024_20p5_w.npz')
chinchilla1024_20p5_wo = np.load('083017_chinchilla1024_20p5_wo.npz')
chinchilla1024_21p0_w = np.load('083017_chinchilla1024_21p0_w.npz')
chinchilla1024_21p0_wo = np.load('083017_chinchilla1024_21p0_wo.npz')

chinchilla2048_20p0_w = np.load('083017_chinchilla2048_20p0_w.npz')
chinchilla2048_20p0_wo = np.load('083017_chinchilla2048_20p0_wo.npz')
chinchilla2048_20p5_w = np.load('083017_chinchilla2048_20p5_w.npz')
chinchilla2048_20p5_wo = np.load('083017_chinchilla2048_20p5_wo.npz')
chinchilla2048_21p0_w = np.load('083017_chinchilla2048_21p0_w.npz')
chinchilla2048_21p0_wo = np.load('083017_chinchilla2048_21p0_wo.npz')

chinchilla2560_20p0_w = np.load('083017_chinchilla2560_20p0_w.npz')
chinchilla2560_20p0_wo = np.load('083017_chinchilla2560_20p0_wo.npz')
chinchilla2560_20p5_w = np.load('083017_chinchilla2560_20p5_w.npz')
chinchilla2560_20p5_wo = np.load('083017_chinchilla2560_20p5_wo.npz')
chinchilla2560_21p0_w = np.load('083017_chinchilla2560_21p0_w.npz')
chinchilla2560_21p0_wo = np.load('083017_chinchilla2560_21p0_wo.npz')

bolshoi_20p0_w = np.load('083017_bolshoi_20p0_w.npz')
bolshoi_20p0_wo = np.load('083017_bolshoi_20p0_wo.npz')
bolshoi_20p5_w = np.load('083017_bolshoi_20p5_w.npz')
bolshoi_20p5_wo = np.load('083017_bolshoi_20p5_wo.npz')
bolshoi_21p0_w = np.load('083017_bolshoi_21p0_w.npz')
bolshoi_21p0_wo = np.load('083017_bolshoi_21p0_wo.npz')

bolplanck_20p0_w = np.load('083017_bolplanck_20p0_w.npz')
bolplanck_20p0_wo = np.load('083017_bolplanck_20p0_wo.npz')
bolplanck_20p5_w = np.load('083017_bolplanck_20p5_w.npz')
bolplanck_20p5_wo = np.load('083017_bolplanck_20p5_wo.npz')
bolplanck_21p0_w = np.load('083017_bolplanck_21p0_w.npz')
bolplanck_21p0_wo = np.load('083017_bolplanck_21p0_wo.npz')

diemer250_20p0_w = np.load('083017_diemer250_20p0_w.npz')
diemer250_20p0_wo = np.load('083017_diemer250_20p0_wo.npz')
diemer250_20p5_w = np.load('083017_diemer250_20p5_w.npz')
diemer250_20p5_wo = np.load('083017_diemer250_20p5_wo.npz')
diemer250_21p0_w = np.load('083017_diemer250_21p0_w.npz')
diemer250_21p0_wo = np.load('083017_diemer250_21p0_wo.npz')

diemer500_20p0_w = np.load('083017_diemer500_20p0_1_w.npz')
diemer500_20p0_wo = np.load('083017_diemer500_20p0_1_wo.npz')
diemer500_20p5_w = np.load('083017_diemer500_20p5_1_w.npz')
diemer500_20p5_wo = np.load('083017_diemer500_20p5_1_wo.npz')
diemer500_21p0_w = np.load('083017_diemer500_21p0_1_w.npz')
diemer500_21p0_wo = np.load('083017_diemer500_21p0_1_wo.npz')

# %%
title_list = ['chinchilla2560,-20.0','chinchilla2560,-20.5','chinchilla2560,-21.0',\
              'bolshoi,-20.0','bolshoi,-20.5','bolshoi,-21.0',\
              'chinchilla2048,-20.0','chinchilla2048,-20.5','chinchilla2048,-21.0',\
              'bolplanck,-20.0','bolplanck,-20.5','bolplanck,-21.0',\
              'chinchilla1024,-20.0','chinchilla1024,-20.5','chinchilla1024,-21.0',\
              'diemer250,-20.0','diemer250,-20.5','diemer250,-21.0',\
              'consuelo,-20.0','consuelo,-20.5','consuelo,-21.0',\
              'diemer500,-20.0','diemer500,-20.5','diemer500,-21.0',\
              'chinchilla512,-20.0','chinchilla512,-20.5','chinchilla512,-21.0']

# %%
c = []

c.append(correlation(chinchilla2560_20p0_w,chinchilla2560_20p0_wo))
c.append(correlation(chinchilla2560_20p5_w,chinchilla2560_20p5_wo))
c.append(correlation(chinchilla2560_21p0_w,chinchilla2560_21p0_wo))

c.append(correlation(bolshoi_20p0_w,bolshoi_20p0_wo))
c.append(correlation(bolshoi_20p5_w,bolshoi_20p5_wo))
c.append(correlation(bolshoi_21p0_w,bolshoi_21p0_wo))

c.append(correlation(chinchilla2048_20p0_w,chinchilla2048_20p0_wo))
c.append(correlation(chinchilla2048_20p5_w,chinchilla2048_20p5_wo))
c.append(correlation(chinchilla2048_21p0_w,chinchilla2048_21p0_wo))

c.append(correlation(bolplanck_20p0_w,bolplanck_20p0_wo))
c.append(correlation(bolplanck_20p5_w,bolplanck_20p5_wo))
c.append(correlation(bolplanck_21p0_w,bolplanck_21p0_wo))

c.append(correlation(chinchilla1024_20p0_w,chinchilla1024_20p0_wo))
c.append(correlation(chinchilla1024_20p5_w,chinchilla1024_20p5_wo))
c.append(correlation(chinchilla1024_21p0_w,chinchilla1024_21p0_wo))

c.append(correlation(diemer250_20p0_w,diemer250_20p0_wo))
c.append(correlation(diemer250_20p5_w,diemer250_20p5_wo))
c.append(correlation(diemer250_21p0_w,diemer250_21p0_wo))

c.append(correlation(consuelo_20p0_w,consuelo_20p0_wo))
c.append(correlation(consuelo_20p5_w,consuelo_20p5_wo))
c.append(correlation(consuelo_21p0_w,consuelo_21p0_wo))

c.append(correlation(diemer500_20p0_w,diemer500_20p0_wo))
c.append(correlation(diemer500_20p5_w,diemer500_20p5_wo))
c.append(correlation(diemer500_21p0_w,diemer500_21p0_wo))

c.append(correlation(chinchilla512_20p0_w,chinchilla512_20p0_wo))
c.append(correlation(chinchilla512_20p5_w,chinchilla512_20p5_wo))
c.append(correlation(chinchilla512_21p0_w,chinchilla512_21p0_wo))

# %%
fig = plt.figure(figsize=(30,90))
for i in range(1,28):
    fig.add_subplot(9,3,i)
    plt.title(title_list[i-1],fontsize=30)
    c[i-1].plot_correlation_matrix()

# %%
title_list_1 = ['chinchilla2560,-20.0','chinchilla2560,-20.5','chinchilla2560,-21.0',\
              'chinchilla2048,-20.0','chinchilla2048,-20.5','chinchilla2048,-21.0',\
              'chinchilla2560,-20.0,sigma_logM selection1','chinchilla2560,-20.5,sigma_logM selection1',\
                'chinchilla2560,-21.0,sigma_logM selection1',\
              'chinchilla2048,-20.0,sigma_logM selection1','chinchilla2048,-20.5,sigma_logM selection1',\
                'chinchilla2048,-21.0,sigma_logM selection1',\
              'chinchilla2560,-20.0,sigma_logM selection2',\
                'chinchilla2560,-20.5,sigma_logM selection2',\
                'chinchilla2560,-21.0,sigma_logM selection2',\
              'chinchilla2048,-20.0,sigma_logM selection2',\
                'chinchilla2048,-20.5,sigma_logM selection2',\
                'chinchilla2048,-21.0,sigma_logM selection2']

# %%
chinchilla2048_slm_20p0_w = np.load('090417_chinchilla2048_select_slm_20p0_w.npz')
chinchilla2048_slm_20p0_wo = np.load('090417_chinchilla2048_select_slm_20p0_wo.npz')
chinchilla2048_slm_20p5_w = np.load('090417_chinchilla2048_select_slm_20p5_w.npz')
chinchilla2048_slm_20p5_wo = np.load('090417_chinchilla2048_select_slm_20p5_wo.npz')
chinchilla2048_slm_21p0_w = np.load('090417_chinchilla2048_select_slm_21p0_w.npz')
chinchilla2048_slm_21p0_wo = np.load('090417_chinchilla2048_select_slm_21p0_wo.npz')

chinchilla2560_slm_20p0_w = np.load('090417_chinchilla2560_select_slm_20p0_w.npz')
chinchilla2560_slm_20p0_wo = np.load('090417_chinchilla2560_select_slm_20p0_wo.npz')
chinchilla2560_slm_20p5_w = np.load('090417_chinchilla2560_select_slm_20p5_w.npz')
chinchilla2560_slm_20p5_wo = np.load('090417_chinchilla2560_select_slm_20p5_wo.npz')
chinchilla2560_slm_21p0_w = np.load('090417_chinchilla2560_select_slm_21p0_w.npz')
chinchilla2560_slm_21p0_wo = np.load('090417_chinchilla2560_select_slm_21p0_wo.npz')

chinchilla2048_anti_slm_20p0_w = np.load('090417_chinchilla2048_anti_select_slm_20p0_w.npz')
chinchilla2048_anti_slm_20p0_wo = np.load('090417_chinchilla2048_anti_select_slm_20p0_wo.npz')
chinchilla2048_anti_slm_20p5_w = np.load('090417_chinchilla2048_anti_select_slm_20p5_w.npz')
chinchilla2048_anti_slm_20p5_wo = np.load('090417_chinchilla2048_anti_select_slm_20p5_wo.npz')
chinchilla2048_anti_slm_21p0_w = np.load('090417_chinchilla2048_anti_select_slm_21p0_w.npz')
chinchilla2048_anti_slm_21p0_wo = np.load('090417_chinchilla2048_anti_select_slm_21p0_wo.npz')

chinchilla2560_anti_slm_20p0_w = np.load('090417_chinchilla2560_anti_select_slm_20p0_w.npz')
chinchilla2560_anti_slm_20p0_wo = np.load('090417_chinchilla2560_anti_select_slm_20p0_wo.npz')
chinchilla2560_anti_slm_20p5_w = np.load('090417_chinchilla2560_anti_select_slm_20p5_w.npz')
chinchilla2560_anti_slm_20p5_wo = np.load('090417_chinchilla2560_anti_select_slm_20p5_wo.npz')
chinchilla2560_anti_slm_21p0_w = np.load('090417_chinchilla2560_anti_select_slm_21p0_w.npz')
chinchilla2560_anti_slm_21p0_wo = np.load('090417_chinchilla2560_anti_select_slm_21p0_wo.npz')

# %%
c_1 = []

c_1.append(correlation(chinchilla2560_20p0_w,chinchilla2560_20p0_wo))
c_1.append(correlation(chinchilla2560_20p5_w,chinchilla2560_20p5_wo))
c_1.append(correlation(chinchilla2560_21p0_w,chinchilla2560_21p0_wo))

c_1.append(correlation(chinchilla2048_20p0_w,chinchilla2048_20p0_wo))
c_1.append(correlation(chinchilla2048_20p5_w,chinchilla2048_20p5_wo))
c_1.append(correlation(chinchilla2048_21p0_w,chinchilla2048_21p0_wo))

c_1.append(correlation(chinchilla2560_slm_20p0_w,chinchilla2560_slm_20p0_wo))
c_1.append(correlation(chinchilla2560_slm_20p5_w,chinchilla2560_slm_20p5_wo))
c_1.append(correlation(chinchilla2560_slm_21p0_w,chinchilla2560_slm_21p0_wo))

c_1.append(correlation(chinchilla2048_slm_20p0_w,chinchilla2048_slm_20p0_wo))
c_1.append(correlation(chinchilla2048_slm_20p5_w,chinchilla2048_slm_20p5_wo))
c_1.append(correlation(chinchilla2048_slm_21p0_w,chinchilla2048_slm_21p0_wo))

c_1.append(correlation(chinchilla2560_anti_slm_20p0_w,chinchilla2560_anti_slm_20p0_wo))
c_1.append(correlation(chinchilla2560_anti_slm_20p5_w,chinchilla2560_anti_slm_20p5_wo))
c_1.append(correlation(chinchilla2560_anti_slm_21p0_w,chinchilla2560_anti_slm_21p0_wo))

c_1.append(correlation(chinchilla2048_anti_slm_20p0_w,chinchilla2048_anti_slm_20p0_wo))
c_1.append(correlation(chinchilla2048_anti_slm_20p5_w,chinchilla2048_anti_slm_20p5_wo))
c_1.append(correlation(chinchilla2048_anti_slm_21p0_w,chinchilla2048_anti_slm_21p0_wo))

# %%
fig = plt.figure(figsize=(30,60))
for i in range(1,19):
    fig.add_subplot(6,3,i)
    plt.title(title_list_1[i-1],fontsize=30)
    c_1[i-1].plot_correlation_matrix()
