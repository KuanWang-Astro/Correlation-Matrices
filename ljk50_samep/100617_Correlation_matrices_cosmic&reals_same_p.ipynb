# %%
import numpy as np
import matplotlib.pyplot as plt
np.set_printoptions(threshold=np.inf)
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
from cosmic_correlation_matrix import correlation

# %%
consuelo_20p0_w = np.load('consuelo_20p0_jk_reals_w.npz')
consuelo_20p0_wo = np.load('consuelo_20p0_jk_reals_wo.npz')
consuelo_20p5_w = np.load('consuelo_20p5_jk_reals_w.npz')
consuelo_20p5_wo = np.load('consuelo_20p5_jk_reals_wo.npz')
consuelo_21p0_w = np.load('consuelo_21p0_jk_reals_w.npz')
consuelo_21p0_wo = np.load('consuelo_21p0_jk_reals_wo.npz')

chinchilla512_20p0_w = np.load('chinchilla512_20p0_jk_reals_w.npz')
chinchilla512_20p0_wo = np.load('chinchilla512_20p0_jk_reals_wo.npz')
chinchilla512_20p5_w = np.load('chinchilla512_20p5_jk_reals_w.npz')
chinchilla512_20p5_wo = np.load('chinchilla512_20p5_jk_reals_wo.npz')
chinchilla512_21p0_w = np.load('chinchilla512_21p0_jk_reals_w.npz')
chinchilla512_21p0_wo = np.load('chinchilla512_21p0_jk_reals_wo.npz')

chinchilla1024_20p0_w = np.load('chinchilla1024_20p0_jk_reals_w.npz')
chinchilla1024_20p0_wo = np.load('chinchilla1024_20p0_jk_reals_wo.npz')
chinchilla1024_20p5_w = np.load('chinchilla1024_20p5_jk_reals_w.npz')
chinchilla1024_20p5_wo = np.load('chinchilla1024_20p5_jk_reals_wo.npz')
chinchilla1024_21p0_w = np.load('chinchilla1024_21p0_jk_reals_w.npz')
chinchilla1024_21p0_wo = np.load('chinchilla1024_21p0_jk_reals_wo.npz')

chinchilla2048_20p0_w = np.load('chinchilla2048_20p0_jk_reals_w.npz')
chinchilla2048_20p0_wo = np.load('chinchilla2048_20p0_jk_reals_wo.npz')
chinchilla2048_20p5_w = np.load('chinchilla2048_20p5_jk_reals_w.npz')
chinchilla2048_20p5_wo = np.load('chinchilla2048_20p5_jk_reals_wo.npz')
chinchilla2048_21p0_w = np.load('chinchilla2048_21p0_jk_reals_w.npz')
chinchilla2048_21p0_wo = np.load('chinchilla2048_21p0_jk_reals_wo.npz')

chinchilla2560_20p0_w = np.load('chinchilla2560_20p0_jk_reals_w.npz')
chinchilla2560_20p0_wo = np.load('chinchilla2560_20p0_jk_reals_wo.npz')
chinchilla2560_20p5_w = np.load('chinchilla2560_20p5_jk_reals_w.npz')
chinchilla2560_20p5_wo = np.load('chinchilla2560_20p5_jk_reals_wo.npz')
chinchilla2560_21p0_w = np.load('chinchilla2560_21p0_jk_reals_w.npz')
chinchilla2560_21p0_wo = np.load('chinchilla2560_21p0_jk_reals_wo.npz')

bolshoi_20p0_w = np.load('bolshoi_20p0_jk_reals_w.npz')
bolshoi_20p0_wo = np.load('bolshoi_20p0_jk_reals_wo.npz')
bolshoi_20p5_w = np.load('bolshoi_20p5_jk_reals_w.npz')
bolshoi_20p5_wo = np.load('bolshoi_20p5_jk_reals_wo.npz')
bolshoi_21p0_w = np.load('bolshoi_21p0_jk_reals_w.npz')
bolshoi_21p0_wo = np.load('bolshoi_21p0_jk_reals_wo.npz')

bolplanck_20p0_w = np.load('bolplanck_20p0_jk_reals_w.npz')
bolplanck_20p0_wo = np.load('bolplanck_20p0_jk_reals_wo.npz')
bolplanck_20p5_w = np.load('bolplanck_20p5_jk_reals_w.npz')
bolplanck_20p5_wo = np.load('bolplanck_20p5_jk_reals_wo.npz')
bolplanck_21p0_w = np.load('bolplanck_21p0_jk_reals_w.npz')
bolplanck_21p0_wo = np.load('bolplanck_21p0_jk_reals_wo.npz')

diemer250_20p0_w = np.load('diemer250_20p0_jk_reals_w.npz')
diemer250_20p0_wo = np.load('diemer250_20p0_jk_reals_wo.npz')
diemer250_20p5_w = np.load('diemer250_20p5_jk_reals_w.npz')
diemer250_20p5_wo = np.load('diemer250_20p5_jk_reals_wo.npz')
diemer250_21p0_w = np.load('diemer250_21p0_jk_reals_w.npz')
diemer250_21p0_wo = np.load('diemer250_21p0_jk_reals_wo.npz')

diemer500_20p0_w = np.load('diemer500_20p0_jk_reals_w.npz')
diemer500_20p0_wo = np.load('diemer500_20p0_jk_reals_wo.npz')
diemer500_20p5_w = np.load('diemer500_20p5_jk_reals_w.npz')
diemer500_20p5_wo = np.load('diemer500_20p5_jk_reals_wo.npz')
diemer500_21p0_w = np.load('diemer500_21p0_jk_reals_w.npz')
diemer500_21p0_wo = np.load('diemer500_21p0_jk_reals_wo.npz')

# %%
title_list = ['chinchilla2560,-20.0','chinchilla2560,-20.5','chinchilla2560,-21.0',\
              'bolshoi,-20.0','bolshoi,-20.5','bolshoi,-21.0',\
              'chinchilla2048,-20.0','chinchilla2048,-20.5','chinchilla2048,-21.0',\
              'bolplanck,-20.0','bolplanck,-20.5','bolplanck,-21.0',\
              'chinchilla1024,-20.0','chinchilla1024,-20.5','chinchilla1024,-21.0',\
              'diemer250,-20.0','diemer250,-20.5','diemer250,-21.0',\
              'consuelo,-20.0','consuelo,-20.5','consuelo,-21.0',\
              'diemer500,-20.0','diemer500,-20.5','diemer500,-21.0',\
              'chinchilla512,-20.0','chinchilla512,-20.5','chinchilla512,-21.0']

# %%
c = []

c.append(correlation(chinchilla2560_20p0_w,chinchilla2560_20p0_wo))
c.append(correlation(chinchilla2560_20p5_w,chinchilla2560_20p5_wo))
c.append(correlation(chinchilla2560_21p0_w,chinchilla2560_21p0_wo))

c.append(correlation(bolshoi_20p0_w,bolshoi_20p0_wo))
c.append(correlation(bolshoi_20p5_w,bolshoi_20p5_wo))
c.append(correlation(bolshoi_21p0_w,bolshoi_21p0_wo))

c.append(correlation(chinchilla2048_20p0_w,chinchilla2048_20p0_wo))
c.append(correlation(chinchilla2048_20p5_w,chinchilla2048_20p5_wo))
c.append(correlation(chinchilla2048_21p0_w,chinchilla2048_21p0_wo))

c.append(correlation(bolplanck_20p0_w,bolplanck_20p0_wo))
c.append(correlation(bolplanck_20p5_w,bolplanck_20p5_wo))
c.append(correlation(bolplanck_21p0_w,bolplanck_21p0_wo))

c.append(correlation(chinchilla1024_20p0_w,chinchilla1024_20p0_wo))
c.append(correlation(chinchilla1024_20p5_w,chinchilla1024_20p5_wo))
c.append(correlation(chinchilla1024_21p0_w,chinchilla1024_21p0_wo))

c.append(correlation(diemer250_20p0_w,diemer250_20p0_wo))
c.append(correlation(diemer250_20p5_w,diemer250_20p5_wo))
c.append(correlation(diemer250_21p0_w,diemer250_21p0_wo))

c.append(correlation(consuelo_20p0_w,consuelo_20p0_wo))
c.append(correlation(consuelo_20p5_w,consuelo_20p5_wo))
c.append(correlation(consuelo_21p0_w,consuelo_21p0_wo))

c.append(correlation(diemer500_20p0_w,diemer500_20p0_wo))
c.append(correlation(diemer500_20p5_w,diemer500_20p5_wo))
c.append(correlation(diemer500_21p0_w,diemer500_21p0_wo))

c.append(correlation(chinchilla512_20p0_w,chinchilla512_20p0_wo))
c.append(correlation(chinchilla512_20p5_w,chinchilla512_20p5_wo))
c.append(correlation(chinchilla512_21p0_w,chinchilla512_21p0_wo))

# %%
fig = plt.figure(figsize=(30,90))
for i in range(1,28):
    fig.add_subplot(9,3,i)
    plt.title(title_list[i-1],fontsize=30)
    c[i-1].plot_correlation_matrix(1,0.)

# %%
bins = np.linspace(0.002,0.01,200)

plt.figure()
plt.hist(consuelo_20p0_w['ngals']/(420.0**3),histtype=u'step',bins=bins)
plt.hist(consuelo_20p0_wo['ngals']/(420.0**3),histtype=u'step',bins=bins)
plt.hist(chinchilla512_20p0_w['ngals']/(250.0**3),histtype=u'step',bins=bins)
plt.hist(chinchilla512_20p0_wo['ngals']/(250.0**3),histtype=u'step',bins=bins)
plt.hist(chinchilla1024_20p0_w['ngals']/(250.0**3),histtype=u'step',bins=bins)
plt.hist(chinchilla1024_20p0_wo['ngals']/(250.0**3),histtype=u'step',bins=bins)
plt.hist(chinchilla2048_20p0_w['ngals']/(250.0**3),histtype=u'step',bins=bins)
plt.hist(chinchilla2048_20p0_wo['ngals']/(250.0**3),histtype=u'step',bins=bins)
plt.hist(chinchilla2560_20p0_w['ngals']/(250.0**3),histtype=u'step',bins=bins)
plt.hist(chinchilla2560_20p0_wo['ngals']/(250.0**3),histtype=u'step',bins=bins)
plt.hist(bolshoi_20p0_w['ngals']/(250.0**3),histtype=u'step',bins=bins)
plt.hist(bolshoi_20p0_wo['ngals']/(250.0**3),histtype=u'step',bins=bins)
plt.hist(bolplanck_20p0_w['ngals']/(250.0**3),histtype=u'step',bins=bins)
plt.hist(bolplanck_20p0_wo['ngals']/(250.0**3),histtype=u'step',bins=bins)
plt.hist(diemer250_20p0_w['ngals']/(250.0**3),histtype=u'step',bins=bins)
plt.hist(diemer250_20p0_wo['ngals']/(250.0**3),histtype=u'step',bins=bins)
plt.hist(diemer500_20p0_w['ngals']/(500.0**3),histtype=u'step',bins=bins)
plt.hist(diemer500_20p0_wo['ngals']/(500.0**3),histtype=u'step',bins=bins)
plt.xlabel('galaxy number density[(Mpc/h)^-3]')
plt.ylabel('Frequency')

bins = np.linspace(0.001,0.004,200)
plt.figure()
plt.hist(consuelo_20p5_w['ngals']/(420.0**3),histtype=u'step',bins=bins)
plt.hist(consuelo_20p5_wo['ngals']/(420.0**3),histtype=u'step',bins=bins)
plt.hist(chinchilla512_20p5_w['ngals']/(250.0**3),histtype=u'step',bins=bins)
plt.hist(chinchilla512_20p5_wo['ngals']/(250.0**3),histtype=u'step',bins=bins)
plt.hist(chinchilla1024_20p5_w['ngals']/(250.0**3),histtype=u'step',bins=bins)
plt.hist(chinchilla1024_20p5_wo['ngals']/(250.0**3),histtype=u'step',bins=bins)
plt.hist(chinchilla2048_20p5_w['ngals']/(250.0**3),histtype=u'step',bins=bins)
plt.hist(chinchilla2048_20p5_wo['ngals']/(250.0**3),histtype=u'step',bins=bins)
plt.hist(chinchilla2560_20p5_w['ngals']/(250.0**3),histtype=u'step',bins=bins)
plt.hist(chinchilla2560_20p5_wo['ngals']/(250.0**3),histtype=u'step',bins=bins)
plt.hist(bolshoi_20p5_w['ngals']/(250.0**3),histtype=u'step',bins=bins)
plt.hist(bolshoi_20p5_wo['ngals']/(250.0**3),histtype=u'step',bins=bins)
plt.hist(bolplanck_20p5_w['ngals']/(250.0**3),histtype=u'step',bins=bins)
plt.hist(bolplanck_20p5_wo['ngals']/(250.0**3),histtype=u'step',bins=bins)
plt.hist(diemer250_20p5_w['ngals']/(250.0**3),histtype=u'step',bins=bins)
plt.hist(diemer250_20p5_wo['ngals']/(250.0**3),histtype=u'step',bins=bins)
plt.hist(diemer500_20p5_w['ngals']/(500.0**3),histtype=u'step',bins=bins)
plt.hist(diemer500_20p5_wo['ngals']/(500.0**3),histtype=u'step',bins=bins)
plt.xlabel('galaxy number density[(Mpc/h)^-3]')
plt.ylabel('Frequency')

bins = np.linspace(0.0005,0.0015,200)
plt.figure()
plt.hist(consuelo_21p0_w['ngals']/(420.0**3),histtype=u'step',bins=bins)
plt.hist(consuelo_21p0_wo['ngals']/(420.0**3),histtype=u'step',bins=bins)
plt.hist(chinchilla512_21p0_w['ngals']/(250.0**3),histtype=u'step',bins=bins)
plt.hist(chinchilla512_21p0_wo['ngals']/(250.0**3),histtype=u'step',bins=bins)
plt.hist(chinchilla1024_21p0_w['ngals']/(250.0**3),histtype=u'step',bins=bins)
plt.hist(chinchilla1024_21p0_wo['ngals']/(250.0**3),histtype=u'step',bins=bins)
plt.hist(chinchilla2048_21p0_w['ngals']/(250.0**3),histtype=u'step',bins=bins)
plt.hist(chinchilla2048_21p0_wo['ngals']/(250.0**3),histtype=u'step',bins=bins)
plt.hist(chinchilla2560_21p0_w['ngals']/(250.0**3),histtype=u'step',bins=bins)
plt.hist(chinchilla2560_21p0_wo['ngals']/(250.0**3),histtype=u'step',bins=bins)
plt.hist(bolshoi_21p0_w['ngals']/(250.0**3),histtype=u'step',bins=bins)
plt.hist(bolshoi_21p0_wo['ngals']/(250.0**3),histtype=u'step',bins=bins)
plt.hist(bolplanck_21p0_w['ngals']/(250.0**3),histtype=u'step',bins=bins)
plt.hist(bolplanck_21p0_wo['ngals']/(250.0**3),histtype=u'step',bins=bins)
plt.hist(diemer250_21p0_w['ngals']/(250.0**3),histtype=u'step',bins=bins)
plt.hist(diemer250_21p0_wo['ngals']/(250.0**3),histtype=u'step',bins=bins)
plt.hist(diemer500_21p0_w['ngals']/(500.0**3),histtype=u'step',bins=bins)
plt.hist(diemer500_21p0_wo['ngals']/(500.0**3),histtype=u'step',bins=bins)
plt.xlabel('galaxy number density[(Mpc/h)^-3]')
plt.ylabel('Frequency')

# %%
print np.mean(chinchilla512_20p0_w['ngals'])
print np.mean(chinchilla512_20p0_wo['ngals'])
# Out:
# 36343.4
# 39718.472

# %%
print np.mean(bolshoi_20p0_w['ngals'])
print np.mean(bolshoi_20p0_wo['ngals'])
# Out:
# 87419.148
# 86028.668

# %%
print np.mean(consuelo_20p0_w['ngals'])/(42./25.)**3
print np.mean(consuelo_20p0_wo['ngals'])/(42./25.)**3
# Out:
# 54988.7730638
# 73007.7095818

# %%
from halotools.sim_manager import CachedHaloCatalog

# %%
halocat = CachedHaloCatalog(simname = 'chinchilla', version_name = '250-2560',redshift = 0, \
                                halo_finder = 'rockstar')
plt.hist(halocat.halo_table['halo_mvir'],bins=np.logspace(10,15.1,20),histtype=u'step',label='chinchilla2560')
halocat = CachedHaloCatalog(simname = 'bolshoi', version_name = 'halotools_v0p4',redshift = 0, \
                                halo_finder = 'rockstar')
plt.hist(halocat.halo_table['halo_mvir'],bins=np.logspace(10,15.1,20),histtype=u'step',label='bolshoi')
halocat = CachedHaloCatalog(simname = 'chinchilla', version_name = '250-2048',redshift = 0, \
                                halo_finder = 'rockstar')
plt.hist(halocat.halo_table['halo_mvir'],bins=np.logspace(10,15.1,20),histtype=u'step',label='chinchilla2048')
halocat = CachedHaloCatalog(simname = 'bolplanck', version_name = 'halotools_v0p4',redshift = 0, \
                                halo_finder = 'rockstar')
plt.hist(halocat.halo_table['halo_mvir'],bins=np.logspace(10,15.1,20),histtype=u'step',label='bolplanck')
halocat = CachedHaloCatalog(simname = 'chinchilla', version_name = '250-1024',redshift = 0, \
                                halo_finder = 'rockstar')
plt.hist(halocat.halo_table['halo_mvir'],bins=np.logspace(10,15.1,20),histtype=u'step',label='chinchilla1024')
halocat = CachedHaloCatalog(simname = 'diemerL0250', version_name = 'antonio',redshift = 0, \
                                halo_finder = 'rockstar')
plt.hist(halocat.halo_table['halo_mvir'],bins=np.logspace(10,15.1,20),histtype=u'step',label='diemer250')
halocat = CachedHaloCatalog(simname = 'consuelo', version_name = 'halotools_v0p4',redshift = 0, \
                                halo_finder = 'rockstar')
plt.hist(halocat.halo_table['halo_mvir'],bins=np.logspace(10,15.1,20),histtype=u'step',label='consuelo',\
         weights=0*halocat.halo_table['halo_mvir']+(250./420.)**3)
halocat = CachedHaloCatalog(simname = 'diemerL0500', version_name = 'antonio',redshift = 0, \
                                halo_finder = 'rockstar')
plt.hist(halocat.halo_table['halo_mvir'],bins=np.logspace(10,15.1,20),histtype=u'step',label='diemer500',\
         weights=0*halocat.halo_table['halo_mvir']+(250./500.)**3)
halocat = CachedHaloCatalog(simname = 'chinchilla', version_name = '250-512',redshift = 0, \
                                halo_finder = 'rockstar')
plt.hist(halocat.halo_table['halo_mvir'],bins=np.logspace(10,15.1,20),histtype=u'step',label='chinchilla512')
plt.semilogx()
plt.legend()

plt.xlabel('M/M_sun')
plt.ylabel('Number of halos')

# %%
print consuelo_20p0_w['param'][0]
# Out:
# [  1.02654941  13.1879107    0.87818971  12.10313919  12.26929428
#    0.91596941   0.02586083]

# %% [markdown]
# alpha, logM1, sigma_logM, logM0, logMmin, Acen, Asat

# %%
halocat = CachedHaloCatalog(simname = 'chinchilla', version_name = '250-2560',redshift = 0, \
                                halo_finder = 'rockstar')
plt.hist(halocat.halo_table['halo_mvir'],bins=np.logspace(12,15.1,50),histtype=u'step',label='chinchilla2560')
halocat = CachedHaloCatalog(simname = 'bolshoi', version_name = 'halotools_v0p4',redshift = 0, \
                                halo_finder = 'rockstar')
plt.hist(halocat.halo_table['halo_mvir'],bins=np.logspace(12,15.1,50),histtype=u'step',label='bolshoi')
halocat = CachedHaloCatalog(simname = 'chinchilla', version_name = '250-2048',redshift = 0, \
                                halo_finder = 'rockstar')
plt.hist(halocat.halo_table['halo_mvir'],bins=np.logspace(12,15.1,50),histtype=u'step',label='chinchilla2048')
halocat = CachedHaloCatalog(simname = 'bolplanck', version_name = 'halotools_v0p4',redshift = 0, \
                                halo_finder = 'rockstar')
plt.hist(halocat.halo_table['halo_mvir'],bins=np.logspace(12,15.1,50),histtype=u'step',label='bolplanck')
halocat = CachedHaloCatalog(simname = 'chinchilla', version_name = '250-1024',redshift = 0, \
                                halo_finder = 'rockstar')
plt.hist(halocat.halo_table['halo_mvir'],bins=np.logspace(12,15.1,50),histtype=u'step',label='chinchilla1024')
halocat = CachedHaloCatalog(simname = 'diemerL0250', version_name = 'antonio',redshift = 0, \
                                halo_finder = 'rockstar')
plt.hist(halocat.halo_table['halo_mvir'],bins=np.logspace(12,15.1,50),histtype=u'step',label='diemer250')
halocat = CachedHaloCatalog(simname = 'consuelo', version_name = 'halotools_v0p4',redshift = 0, \
                                halo_finder = 'rockstar')
plt.hist(halocat.halo_table['halo_mvir'],bins=np.logspace(12,15.1,50),histtype=u'step',label='consuelo',\
         weights=0*halocat.halo_table['halo_mvir']+(250./420.)**3)
halocat = CachedHaloCatalog(simname = 'diemerL0500', version_name = 'antonio',redshift = 0, \
                                halo_finder = 'rockstar')
plt.hist(halocat.halo_table['halo_mvir'],bins=np.logspace(12,15.1,50),histtype=u'step',label='diemer500',\
         weights=0*halocat.halo_table['halo_mvir']+(250./500.)**3)
halocat = CachedHaloCatalog(simname = 'chinchilla', version_name = '250-512',redshift = 0, \
                                halo_finder = 'rockstar')
plt.hist(halocat.halo_table['halo_mvir'],bins=np.logspace(12,15.1,50),histtype=u'step',label='chinchilla512')
plt.semilogx()
plt.legend()
plt.xlabel('M/M_sun')
plt.ylabel('Number of halos')

# %%
from halotools.empirical_models import PrebuiltHodModelFactory
model = PrebuiltHodModelFactory('zheng07', threshold=-20)

# %%
halocat = CachedHaloCatalog(simname = 'bolshoi', version_name = 'halotools_v0p4',redshift = 0, \
                                halo_finder = 'rockstar')
model.populate_mock(halocat)
print model.param_dict
print len(model.mock.galaxy_table)
# Out:
# {'logM0': 11.38, 'sigma_logM': 0.26, 'logMmin': 12.02, 'alpha': 1.06, 'logM1': 13.31}
# 74721

# %%
halocat = CachedHaloCatalog(simname = 'chinchilla', version_name = '250-512',redshift = 0, \
                                halo_finder = 'rockstar')
model.populate_mock(halocat)
print model.param_dict
print len(model.mock.galaxy_table)
# Out:
# {'logM0': 11.38, 'sigma_logM': 0.26, 'logMmin': 12.02, 'alpha': 1.06, 'logM1': 13.31}
# 37760

# %%
halocat = CachedHaloCatalog(simname = 'diemerL0500', version_name = 'antonio',redshift = 0, \
                                halo_finder = 'rockstar')
model.populate_mock(halocat)
print model.param_dict
print len(model.mock.galaxy_table)/8
# Out:
# {'logM0': 11.38, 'sigma_logM': 0.26, 'logMmin': 12.02, 'alpha': 1.06, 'logM1': 13.31}
# 41909

# %%
halocat = CachedHaloCatalog(simname = 'bolplanck', version_name = 'halotools_v0p4',redshift = 0, \
                                halo_finder = 'rockstar')
model.populate_mock(halocat)
print model.param_dict
print len(model.mock.galaxy_table)
# Out:
# {'logM0': 11.38, 'sigma_logM': 0.26, 'logMmin': 12.02, 'alpha': 1.06, 'logM1': 13.31}
# 88552
